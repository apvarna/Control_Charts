# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Testing

# %% [markdown]
# #### Testing Rule 2

# %%
from control_chart_class_11 import Control_chart
data_df =  pd.read_excel("dog_treats_data.xlsx", sheet_name='RULE 2')
c_chart =  Control_chart()
c_chart.plot_control_char(data=data_df, kind='x_mean', rules=['Rule 2'])

# %% [markdown]
# X_mean: Based on the chart above, we can observe that the out-of-control points are properly highlighted according to Rule 2. Specifically, samples 13 and 14, as well as samples 23 and 24, show consecutive points that are outside the 2SD warning limits on the same side of the center line. This confirms that the rule is correctly identifying segments

# %%
from control_chart_class_11 import Control_chart
data_df =  pd.read_excel('dog_treats_data.xlsx', sheet_name='RULE 2')
c_chart =  Control_chart()
c_chart.plot_control_char(data=data_df, kind='R', rules=['Rule 2'])

# %% [markdown]
# Range: This Range Control Chart shows that the Rule 2 violations have been correctly identified. Specifically, samples 23 and 24 have been highlighted as out of control, with two out of three consecutive points exceeding the 2SD warning limit (even past the Upper control limit). This indicates that the chart is accurately capturing the points that demonstrate abnormal variation

# %% [markdown]
# #### Testing Rule 4

# %%
from control_chart_class_11 import Control_chart
data_df =  pd.read_excel('dog_treats_data.xlsx', sheet_name='RULE 4')
c_chart =  Control_chart()
c_chart.plot_control_char(data=data_df, kind='x_mean', rules=['Rule 4'])

# %% [markdown]
# X_mean: In this chart, we can see that all the samples from 1 to 12 consistently fall on one side of the center line and are therefore marked in red, satisfying the conditions for Rule 4. Although samples 15 to 22 also appear to stay on one side of the center line, only 8 consecutive points fall within this pattern before the data returns to a more balanced distribution, thus not meeting the full conditions for Rule 4.

# %%
from control_chart_class_11 import Control_chart
data_df =  pd.read_excel('dog_treats_data.xlsx', sheet_name='RULE 4')
c_chart =  Control_chart()
c_chart.plot_control_char(data=data_df, kind='R', rules=['Rule 4'])

# %% [markdown]
# R: For the range control chart displayed, it is evident that consecutive points from sample 1 through sample 11 consistently fall on one side of the center line, fulfilling the criteria for Rule 4. These samples are appropriately marked in red to indicate the systematic pattern. The upward trend continues as more points remain above the center line until reaching sample 21, emphasizing a significant shift in the process variation.

# %% [markdown]
# #### Testing Rule 1

# %%
from control_chart_class_11 import Control_chart
data_df =  pd.read_excel('dog_treats_data.xlsx', sheet_name='RULE 4')
c_chart =  Control_chart()
c_chart.plot_control_char(data=data_df, kind='x_mean', rules=['Rule 1'])

# %%
from control_chart_class_11 import Control_chart
data_df =  pd.read_excel('dog_treats_data.xlsx', sheet_name='RULE 4')
c_chart =  Control_chart()
c_chart.plot_control_char(data=data_df, kind='R', rules=['Rule 1'])

# %% [markdown]
# ### Dataset

# %%
data_df2 = pd.read_excel('Data.xlsx',sheet_name="RULE 2")
data_df4 = pd.read_excel('Data.xlsx',sheet_name="RULE 4")

# %%
factors_df = pd.read_csv('factors.csv') 

factors_df.head()
# Out:
#    sample_size     A2     A3     d2   D3     D4    B3     B4
# 0            2  1.880  2.659  1.128  0.0  3.267  0.00  3.267
# 1            3  1.023  1.954  1.693  0.0  2.574  0.00  2.568
# 2            4  0.729  1.628  2.059  0.0  2.282  0.00  2.266
# 3            5  0.577  1.427  2.326  0.0  2.114  0.00  2.089
# 4            6  0.483  1.287  2.534  0.0  2.004  0.03  1.970

# %% [markdown]
# ### Rule 2

# %%
data_df2.head()
# Out:
#    Unnamed: 0  No          x1         x2          x3          x4          x5  \
# 0           0   1  101.174798  98.486464   95.495927  102.029449  113.122803
# 1           1   2  103.844307  96.910676  129.792944   91.060483  106.749426
# 2           2   3   99.777449  92.223841   83.773743   87.840529   93.526872
# 3           3   4   73.498362  97.449733   83.346235  112.648661   96.566622
# 4           4   5   87.422500  99.053535   99.514802   96.589674  108.017336
#
#            x6          x7          x8          x9
# 0  107.846681   82.483640   99.924456   98.232453
# 1   90.637249  111.172274   91.284952  109.180557
# 2   86.923875   95.385304   91.836767  104.438240
# 3   90.727676   79.067997   99.436908   98.199005
# 4  109.865433   95.018553  114.158117   97.317042

# %%
data_df2.drop('Unnamed: 0', axis = 1, inplace = True) #we can remove the Unnamed:0 column as it represents the index

# %%
data_df2.head()
# Out:
#    No          x1         x2          x3          x4          x5          x6  \
# 0   1  101.174798  98.486464   95.495927  102.029449  113.122803  107.846681
# 1   2  103.844307  96.910676  129.792944   91.060483  106.749426   90.637249
# 2   3   99.777449  92.223841   83.773743   87.840529   93.526872   86.923875
# 3   4   73.498362  97.449733   83.346235  112.648661   96.566622   90.727676
# 4   5   87.422500  99.053535   99.514802   96.589674  108.017336  109.865433
#
#            x7          x8          x9
# 0   82.483640   99.924456   98.232453
# 1  111.172274   91.284952  109.180557
# 2   95.385304   91.836767  104.438240
# 3   79.067997   99.436908   98.199005
# 4   95.018553  114.158117   97.317042

# %%
data_df2.shape
# Out:
# (15, 10)

# %% [markdown]
# We have data from 15 unique samples, each consisting of 9 observations.

# %%
data_df2.info() #there are no missing values in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   No      15 non-null     int64
#  1   x1      15 non-null     float64
#  2   x2      15 non-null     float64
#  3   x3      15 non-null     float64
#  4   x4      15 non-null     float64
#  5   x5      15 non-null     float64
#  6   x6      15 non-null     float64
#  7   x7      15 non-null     float64
#  8   x8      15 non-null     float64
#  9   x9      15 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 1.3 KB

# %%
trans_df2 = data_df2.T

trans_df2.head()
# Out:
#             0           1          2           3          4           5   \
# No    1.000000    2.000000   3.000000    4.000000   5.000000    6.000000
# x1  101.174798  103.844307  99.777449   73.498362  87.422500  103.686830
# x2   98.486464   96.910676  92.223841   97.449733  99.053535   94.173124
# x3   95.495927  129.792944  83.773743   83.346235  99.514802   92.367064
# x4  102.029449   91.060483  87.840529  112.648661  96.589674  107.910973
#
#             6           7           8           9           10          11  \
# No    7.000000    8.000000    9.000000   10.000000   11.000000   12.000000
# x1  103.937562   86.672223   82.758536   96.355533  130.850064  113.377608
# x2  103.660825  109.947301   83.806888  107.523475  106.493516  108.584538
# x3   90.812640   94.445033  106.673978  116.374784  105.774512   94.316232
# x4  100.982678  102.885639   95.427786  112.141799  107.462867  102.297410
#
#             12          13          14
# ...

# %% [markdown]
# For future analysis, we want to analyze data by sample, so we need to transpose our DataFrame to ensure that each sample is represented as a column, and the observations are organized as rows

# %%
trans_df2.describe()
# Out:
#                0           1           2           3           4           5   \
# count   10.000000   10.000000   10.000000   10.000000   10.000000   10.000000
# mean    89.979667   93.263287   83.872662   83.494120   91.195699   90.106091
# std     32.264078   34.254431   29.059843   30.142642   31.295842   31.203830
# min      1.000000    2.000000    3.000000    4.000000    5.000000    6.000000
# 25%     96.180059   91.116601   87.153039   80.137556   95.411333   88.417822
# 50%     99.205460  100.377492   92.030304   93.647149   98.185288   97.855058
# 75%    101.815786  108.572774   94.920696   98.011687  105.891703  105.443455
# max    113.122803  129.792944  104.438240  112.648661  114.158117  117.406374
#
#                6           7           8           9           10          11  \
# count   10.000000   10.000000   10.000000   10.000000   10.000000   10.000000
# mean    90.450193   92.961985   90.767532   96.269245   99.909664   94.860079
# ...

# %% [markdown]
# * The sample means generally fall between 99-105, indicating a central tendency that is relatively consistent across the data, suggesting stable observations with only slight deviations.
#     * Samples 3 and 13 have noticeably lower means compared to others, which could indicate different underlying characteristics or anomalies affecting these data points.
#
# * Sample 2 has the highest standard deviation, showing the greatest variability among the samples, while Sample 15 has the lowest, indicating it has the most consistent data points
#
# * Samples such as Sample 11 have significantly higher maximum values (e.g., 130.85), which could suggest potential outliers or exceptional observations within those samples.
#
# * Most samples show relatively symmetric distributions since the mean is close to the median, except for a few with higher Sd, which might indicate some skewness or irregular data distribution within those samples.

# %%
trans_df2 = data_df2.set_index('No').transpose()

trans_df2.iloc[1:].hist(bins=10, figsize=(15, 10))
plt.suptitle('Histograms of Each Sample')
plt.show()

# %% [markdown]
# * Samples like 3, 7, and 14 display a wider range of data points, indicating more variability within those samples. On the other hand, Sample 15 shows a more concentrated set of data points, indicating less variability and a more uniform distribution.
#
# * Samples such as 2 and 10 show high values that stand apart from the majority of data points, potentially indicating outliers or exceptional observations within those datasets.

# %%
trans_df2 = data_df2.set_index('No').transpose()


plt.figure(figsize=(15, 8))
sns.boxplot(data=trans_df2)
plt.title('Boxplots of Observations per Sample')
plt.xlabel('Sample Number')
plt.ylabel('Observation Value')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * samples 2, 10, and 11 show the highest variability with wider interquartile ranges (IQR), indicating a larger spread of observation values within those samples. In contrast, Sample 1 and Sample 15 have narrower IQRs (more consistency in data)
#
# * The median observation values vary across samples. Sample 10 and 11 has one of the highest medians, while Sample 3 and Sample 13 have lower median values, highlighting differences in central tendencies among the samples.

# %% [markdown]
# ### Control Charts - Rule 2

# %%
from control_chart_class_11 import Control_chart
data_df =  pd.read_excel('Data.xlsx', sheet_name='RULE 2')
c_chart =  Control_chart()
c_chart.plot_control_char(data=data_df, kind='x_mean', rules=['Rule 2'])

# %%
from control_chart_class_11 import Control_chart
data_df =  pd.read_excel('Data.xlsx', sheet_name='RULE 2')
c_chart =  Control_chart()
c_chart.plot_control_char(data=data_df, kind='R', rules=['Rule 2'])

# %% [markdown]
# ### Results Rule 2

# %% [markdown]
# X_Mean Control Chart: The control chart shows that the process is generally stable, staying within the control limits, with some fluctuations. However, samples 3 and 4 are marked as outliers, falling outside the 2SD warning limits, making the process out of control. The observed violations of Rule 2, where two consecutive points exceed the 2SD warning limits on the same side of the centerline, suggest a potential trend or shift in the process that could escalate into a control issue if not addressed.
#
# Range Control Chart: The range control chart reveals that most of the sample ranges fall within the control limits, indicating a generally stable process.

# %% [markdown]
# **Potential Causes**
#
# * Variations in raw material quality: This could impact the consistency of outputs.
# * Human error or deviations: Inconsistent procedures by operators might cause fluctuations.
# * Equipment issues: Wear, tear, or insufficient maintenance may contribute to process variability.
#
# **Recommendations**
# * Immediate Investigation: Examine samples 3 and 4 to identify underlying causes of the outliers.
# * Proactive Maintenance: Schedule regular checks and quality assessments to detect and address potential process shifts early, ensuring consistent and controlled operations.

# %% [markdown]
# ### Rule 4

# %%
data_df4.head()
# Out:
#    No         x1         x2         x3         x4         x5         x6  \
# 0   1  12.483571   9.308678  13.238443  17.615149   8.829233   8.829315
# 1   2  17.260565   9.478305  10.424875   2.510688   7.336985  11.019363
# 2   3  11.998320  10.366483   8.519072   7.553434   1.016956   5.590417
# 3   4   7.078133   8.329613   4.224028   3.970521  13.223920  15.965898
# 4   5   7.686994  11.028222  15.751417   7.403767   5.375488   6.755668
#
#           x7         x8         x9  ...        x11        x12        x13  \
# 0  17.896064  13.837174   7.652628  ...   7.682912   7.671351  11.209811
# 1   5.686516  12.951326   8.251471  ...   6.750782  20.494271  10.443667
# 2   6.372094  14.146414  11.682114  ...  11.322398   7.376133   5.099073
# 3   9.567537  15.015600  10.619810  ...  11.259641  17.329127   8.186366
# 4  13.543215  11.507535   6.738082  ...   8.769625  13.205083   4.771925
#
#          x14        x15        x16        x17        x18        x19        x20
# ...

# %%
data_df4.shape
# Out:
# (20, 21)

# %% [markdown]
# We have data from 21 unique samples, each consisting of 20 observations.

# %%
data_df4.info() #there are no missing values in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   No      20 non-null     int64
#  1   x1      20 non-null     float64
#  2   x2      20 non-null     float64
#  3   x3      20 non-null     float64
#  4   x4      20 non-null     float64
#  5   x5      20 non-null     float64
#  6   x6      20 non-null     float64
#  7   x7      20 non-null     float64
#  8   x8      20 non-null     float64
#  9   x9      20 non-null     float64
#  10  x10     20 non-null     float64
#  11  x11     20 non-null     float64
#  12  x12     20 non-null     float64
#  13  x13     20 non-null     float64
#  14  x14     20 non-null     float64
#  15  x15     20 non-null     float64
#  16  x16     20 non-null     float64
#  17  x17     20 non-null     float64
#  18  x18     20 non-null     float64
#  19  x19     20 non-null     float64
#  20  x20     20 non-null     float64
# ...

# %%
trans_df4 = data_df4.T

trans_df4.head()
# Out:
#            0          1          2         3          4         5          6   \
# No   1.000000   2.000000   3.000000  4.000000   5.000000  6.000000   7.000000
# x1  12.483571  17.260565  11.998320  7.078133   7.686994  2.041670  13.802244
# x2   9.308678   9.478305  10.366483  8.329613  11.028222  6.916258   4.615364
# x3  13.238443  10.424875   8.519072  4.224028  15.751417  6.390729  16.043739
# x4  17.615149   2.510688   7.553434  3.970521   7.403767  4.871551   3.684707
#
#            7          8          9          10         11         12  \
# No   8.000000   9.000000  10.000000  11.000000  12.000000  13.000000
# x1  10.054065   3.139457  12.451939   9.171448  21.306780   6.037396
# x2  15.752381  10.908425   6.105145   9.397744  -0.028165   9.426318
# x3   1.601749  14.164732   5.704861  12.058994  13.779398  12.524936
# x4   9.584804   4.078666  13.121939  13.038648   1.462861  14.328776
#
#            13         14         15         16         17         18  \
# ...

# %% [markdown]
# For future analysis, we want to analyze data by sample, so we need to transpose our DataFrame to ensure that each sample is represented as a column, and the observations are organized as rows

# %%
trans_df4.describe()
# Out:
#               0          1          2          3          4          5   \
# count  21.000000  21.000000  21.000000  21.000000  21.000000  21.000000
# mean    8.755721   8.854868   8.743818   8.980077   8.728624   9.213593
# std     5.004721   5.061948   4.371252   5.570907   3.383461   5.089379
# min     0.433599   0.964231  -0.214886  -3.860052   1.643061  -0.337312
# 25%     5.459880   5.389321   6.055598   5.273965   6.755668   6.390729
# 50%     8.829233   8.572688   8.519072   8.952712   7.910685   9.428695
# 75%    12.483571  11.354308  11.998320  13.223920  11.028222  10.477895
# max    17.896064  20.494271  14.526027  17.476933  15.751417  22.062838
#
#               6          7          8          9          10         11  \
# count  21.000000  21.000000  21.000000  21.000000  21.000000  21.000000
# mean    9.067834   8.962336   9.230801   9.208427   9.329450   9.317905
# std     5.097801   4.240765   4.962624   3.609121   5.402684   5.898416
# ...

# %% [markdown]
# * Mean Values: The means of the samples vary across a range from approximately 8.54 to 12.56, indicating differences in central tendencies among the samples.
#
# * The 25th and 75th percentiles reveal that some samples have a tighter interquartile range, while others have a broader range, highlighting variations in the distribution's spread.
#
# * The standard deviations range from approximately 3.27 to 5.60, suggesting varying levels of dispersion within the samples, with some being more consistent than others.

# %%
trans_df4 = data_df4.set_index('No').transpose()

trans_df4.iloc[1:].hist(bins=10, figsize=(15, 10))
plt.suptitle('Histograms of Each Sample')
plt.show()

# %% [markdown]
# * The samples display a variety of distribution shapes, ranging from nearly uniform (e.g., sample 1) to more skewed distributions (e.g., sample 2 and 14).
#
# * Certain samples exhibit gaps or potential outliers, such as sample 8 and 12, suggesting irregularities or infrequent values that may warrant further investigation.
#
# * Most histograms show that the data tends to cluster around certain values, with some samples having a more prominent central peak (e.g., sample 3 and 11), indicating a potential common mean or mode within those samples.

# %%
trans_df4 = data_df4.set_index('No').transpose()


plt.figure(figsize=(15, 8))
sns.boxplot(data=trans_df4)
plt.title('Boxplots of Observations per Sample')
plt.xlabel('Sample Number')
plt.ylabel('Observation Value')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# * Overall Consistency: While many of the samples exhibit a consistent spread, there are noticeable differences in the variability across samples. This could indicate different levels of process stability or underlying factors affecting specific samples.
#
# * Median and Data Spread: Most of the samples have medians that are relatively close to the center of the interquartile range (IQR), indicating symmetric data distributions. However, samples like 1 and 14 have more skewed data distributions, with medians closer to one end of the box.
#
# * Outliers: There are several samples with outliers, such as samples 4, 6, 14, and 19. These indicate data points that are significantly different from the rest of the data and may warrant further investigation.

# %% [markdown]
# ### Control Charts - Rule 4

# %%
from control_chart_class_11 import Control_chart
data_df =  pd.read_excel('Data.xlsx', sheet_name='RULE 4')
c_chart =  Control_chart()
c_chart.plot_control_char(data=data_df, kind='x_mean', rules=['Rule 4'])

# %%
from control_chart_class_11 import Control_chart
data_df =  pd.read_excel('Data.xlsx', sheet_name='RULE 4')
c_chart =  Control_chart()
c_chart.plot_control_char(data=data_df, kind='R', rules=['Rule 4'])

# %% [markdown]
# X_Mean control chart: The first 11 samples show consistent behavior around the centerline, but all fall on one side. This indicates that the process is out of control and the as the conditions of rule for are met with at least 9 samples falling on one side of the center line
# Samples 12 to 20 display greater variation, with noticeable shifts and fluctuations.
#
# Range Control Chart: The range control chart shows that the majority of data points remain within the control limits, indicating that the process variation is generally stable and under control.

# %% [markdown]
# **Potential Causes**
# * Systematic shifts: Possible changes in input materials or process methods.
# * Operator influence: Consistent deviations due to training or procedure changes.
# * Environmental factors: External influences affecting the process over time.
#
# **Recommendations**
# * Immediate Action: Investigate the conditions around samples 1 to 11 to identify any systematic issues leading to consecutive points on one side.
# * Monitoring and Analysis: Increase the frequency of checks to detect early signs of random or non-random patterns.
# * Training and Consistency: Ensure operators follow standardized procedures and document any deviations.
# * Environment and Equipment: Evaluate any changes in the environment or equipment performance that could impact the process.
